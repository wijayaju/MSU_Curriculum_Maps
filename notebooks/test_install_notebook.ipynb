# %% [markdown]
# # Welcome to the test notebook, here we will test if everything is working correctly

# %% [markdown]
# ## Test if base Julia is working

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## Test if the main packages are working

# %%
using CurricularAnalytics
using CurricularVisualization
using CSV
using DataFrames

# %% [markdown]
# ## Test CSV reading

# %%
df = CSV.read("../data/Univ_of_Arizona-Aero.csv", DataFrame)

# %% [markdown]
# ## test visualization

# %%
curric = read_csv("../data/Univ_of_Arizona-Aero.csv")
visualize(curric)
