# %% [markdown]
# # Test installation notebook
# Welcome to the test notebook! Here we will test if the Julia environment and the Cirricular Analytics package are working properly.
# You do not need to generate any MSU Degree Plan data to run this notebook, since it is using the Demo Dataset. This is a dataset taken from the Cirricular Analytics documentation and showcases the University Of Arizona's Areospace degree plan.
#
# If you would like to visualize MSU Degree plans, please follow the instructions in the [reproducibility notebook](reproducibility.ipynb) instead!

# %% [markdown]
# ## Test if base Julia is working

# %%
1+1

# %% [markdown]
# If the above cell ran, then your Julia environment is set up correctly! You should see the output `2` when you run that cell.

# %% [markdown]
# ## Test if the main packages are working

# %%
using CurricularAnalytics
using CurricularVisualization
using CSV
using DataFrames

# %% [markdown]
# If the above cell ran correctly, then you should have the CurricularAnalytics and CurricularVisualization packages installed and ready to use. You can now proceed to analyze and visualize curricular data using these packages.

# %% [markdown]
# ## Test CSV reading

# %%
df = CSV.read("../data/Univ_of_Arizona-Aero.csv", DataFrame)

# %% [markdown]
# This cell ensures that the demo data is present and is in the correct format for the CurricularAnalytics package. It reads a CSV file containing course information for the University of Arizona's Aerospace Engineering program and stores it in a DataFrame.

# %% [markdown]
# ## Test Visualization
#
# Run the cell below to generate the test visualization. It should open up in a new window!

# %%
curric = read_csv("../data/Univ_of_Arizona-Aero.csv")
visualize(curric);
